# %%
import pandas as pd
df=pd.read_csv("ndtv_data_final.csv")
df
# Out:
#       Unnamed: 0                            Name     Brand  \
# 0              0  OnePlus 7T Pro McLaren Edition   OnePlus
# 1              1                   Realme X2 Pro    Realme
# 2              2               iPhone 11 Pro Max     Apple
# 3              3                       iPhone 11     Apple
# 4              4                    LG G8X ThinQ        LG
# ...          ...                             ...       ...
# 1354        1354                   Intex Aqua A2     Intex
# 1355        1355     Videocon Infinium Z51 Nova+  Videocon
# 1356        1356                   Intex Aqua Y4     Intex
# 1357        1357                 iBall Andi4 B20     iBall
# 1358        1358             iBall Andi Avonte 5     iBall
#
#                        Model  Battery capacity (mAh)  Screen size (inches)  \
# 0     7T Pro McLaren Edition                    4085                  6.67
# 1                     X2 Pro                    4000                  6.50
# ...

# %%
 df.drop(columns='Unnamed: 0' , axis=-1 , inplace = True)
df
# Out:
#                                 Name     Brand                   Model  \
# 0     OnePlus 7T Pro McLaren Edition   OnePlus  7T Pro McLaren Edition
# 1                      Realme X2 Pro    Realme                  X2 Pro
# 2                  iPhone 11 Pro Max     Apple       iPhone 11 Pro Max
# 3                          iPhone 11     Apple               iPhone 11
# 4                       LG G8X ThinQ        LG               G8X ThinQ
# ...                              ...       ...                     ...
# 1354                   Intex Aqua A2     Intex                 Aqua A2
# 1355     Videocon Infinium Z51 Nova+  Videocon      Infinium Z51 Nova+
# 1356                   Intex Aqua Y4     Intex                 Aqua Y4
# 1357                 iBall Andi4 B20     iBall               Andi4 B20
# 1358             iBall Andi Avonte 5     iBall           Andi Avonte 5
#
#       Battery capacity (mAh)  Screen size (inches) Touchscreen  Resolution x  \
# ...

# %%
upd_df=df[(df["Brand"]=="Apple")
      |(df["Brand"]=="Samsung")
      |(df["Brand"]=="OnePlus")
      |(df["Brand"]=="Realme")
      |(df["Brand"]=="Infinix")
      |(df["Brand"]=="Techno")
      |(df["Brand"]=="Oppo")
      |(df["Brand"]=="Vivo")
      |(df["Brand"]=="Xiaomi")
      |(df["Brand"]=="Nokia")]

upd_df
# Out:
#                                 Name    Brand                   Model  \
# 0     OnePlus 7T Pro McLaren Edition  OnePlus  7T Pro McLaren Edition
# 1                      Realme X2 Pro   Realme                  X2 Pro
# 2                  iPhone 11 Pro Max    Apple       iPhone 11 Pro Max
# 3                          iPhone 11    Apple               iPhone 11
# 5                         OnePlus 7T  OnePlus                      7T
# ...                              ...      ...                     ...
# 1282                      Samsung Z3  Samsung                      Z3
# 1294                       Vivo Y15S     Vivo                    Y15S
# 1295           Samsung Galaxy J1 Ace  Samsung           Galaxy J1 Ace
# 1296                       Vivo Y27L     Vivo                    Y27L
# 1350                         Vivo V1     Vivo                      V1
#
#       Battery capacity (mAh)  Screen size (inches) Touchscreen  Resolution x  \
# ...

# %% [raw]
# WORKING ON COLUMNS = 'Operating system' 'Wi-Fi' 'Front camera'

# %%
selected_columns = ['Operating system', 'Wi-Fi', 'Front camera','Price']
selected_df = upd_df[selected_columns]
print(selected_df.describe())
# 'Operating system' , 'Wi-Fi' cant obtain the same descriptive statistics as you would with numerical data
# Out:
#        Front camera         Price
# count    334.000000     334.00000
# mean      10.855988   17395.50000
# std        8.329863   19335.10741
# min        0.000000    2999.00000
# 25%        5.000000    7999.25000
# 50%        8.000000   10990.00000
# 75%       16.000000   17996.75000
# max       40.000000  174990.00000

# %%
import matplotlib.pyplot as plt
selected_df.hist()
plt.show()

# %%
import pandas as pd
selected_columns = ['Operating system', 'Wi-Fi', 'Front camera','Price']
selected_df = upd_df[selected_columns]
print(selected_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 334 entries, 0 to 1350
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Operating system  334 non-null    object
#  1   Wi-Fi             334 non-null    object
#  2   Front camera      334 non-null    float64
#  3   Price             334 non-null    int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 13.0+ KB
# None

# %%
import pandas as pd
selected_columns = ['Operating system', 'Wi-Fi', 'Front camera' , 'Price']
selected_df = upd_df[selected_columns]
print(selected_df.nunique())
# Out:
# Operating system      5
# Wi-Fi                 2
# Front camera         23
# Price               217
# dtype: int64

# %%
upd_df['Operating system'].value_counts()
# Out:
# Operating system
# Android     298
# iOS          17
# Windows      11
# Cyanogen      5
# Tizen         3
# Name: count, dtype: int64

# %%
upd_df['Wi-Fi'].value_counts()
# Out:
# Wi-Fi
# Yes    332
# No       2
# Name: count, dtype: int64

# %%
upd_df['Front camera'].value_counts()
# Out:
# Front camera
# 5.0     86
# 16.0    59
# 8.0     55
# 32.0    18
# 20.0    16
# 13.0    16
# 2.0     14
# 0.0     10
# 25.0    10
# 24.0     8
# 7.0      8
# 1.2      6
# 10.0     6
# 0.3      6
# 12.0     4
# 1.9      4
# 3.7      2
# 4.0      1
# 1.3      1
# 0.9      1
# 2.1      1
# 1.6      1
# 40.0     1
# Name: count, dtype: int64

# %%
selected_columns = [ 'Front camera','Price']
value_counts = upd_df[['Front camera','Price']].value_counts()
print("value_counts")
print(value_counts)
# Out:
# value_counts
# Front camera  Price
# 5.0           8999     4
# 8.0           8999     4
# 5.0           6999     4
#               7999     3
#               9999     3
#                       ..
#               19999    1
#               21999    1
#               22999    1
#               23999    1
# 40.0          92999    1
# Name: count, Length: 293, dtype: int64

# %%
upd_df['Price'].value_counts()
# Out:
# Price
# 8999     14
# 6999     10
# 7999      9
# 9999      8
# 10990     6
#          ..
# 6899      1
# 17999     1
# 27900     1
# 29950     1
# 15300     1
# Name: count, Length: 217, dtype: int64

# %%
selected_columns = ['Operating system', 'Wi-Fi', 'Front camera','Price']
min_values = df[['Operating system', 'Wi-Fi', 'Front camera','Price']].min()
print("Min values:")
print(min_values)
# Out:
# Min values:
# Operating system    Android
# Wi-Fi                    No
# Front camera            0.0
# Price                   494
# dtype: object

# %%
max_values = upd_df[['Operating system', 'Wi-Fi', 'Front camera' ,'Price']].max()
print("Maximum values:")
print(max_values)
# Out:
# Maximum values:
# Operating system       iOS
# Wi-Fi                  Yes
# Front camera          40.0
# Price               174990
# dtype: object

# %%
df.describe = upd_df[['Front camera', 'Price']].describe()

print("describe")
print(df.describe)
# Out:
# describe
#        Front camera         Price
# count    334.000000     334.00000
# mean      10.855988   17395.50000
# std        8.329863   19335.10741
# min        0.000000    2999.00000
# 25%        5.000000    7999.25000
# 50%        8.000000   10990.00000
# 75%       16.000000   17996.75000
# max       40.000000  174990.00000

# %%
df.describe = upd_df[['Front camera', 'Price', 'Wi-Fi', 'Operating system']].describe()
print("describe")
print(df.describe)
# Out:
# describe
#        Front camera         Price
# count    334.000000     334.00000
# mean      10.855988   17395.50000
# std        8.329863   19335.10741
# min        0.000000    2999.00000
# 25%        5.000000    7999.25000
# 50%        8.000000   10990.00000
# 75%       16.000000   17996.75000
# max       40.000000  174990.00000

# %%
df.sort_values(by='Front camera')
# Out:
#                           Name    Brand             Model  \
# 1358       iBall Andi Avonte 5    iBall     Andi Avonte 5
# 436           Nokia X Dual SIM    Nokia        X Dual SIM
# 443             Nokia Asha 502    Nokia          Asha 502
# 573            Nokia Lumia 525    Nokia         Lumia 525
# 585      Samsung Galaxy Pocket  Samsung     Galaxy Pocket
# ...                        ...      ...               ...
# 79                    Vivo Z1x     Vivo               Z1x
# 96          Samsung Galaxy A70  Samsung        Galaxy A70
# 76                Vivo V17 Pro     Vivo           V17 Pro
# 614   Samsung Galaxy S20 Ultra  Samsung  Galaxy S20 Ultra
# 89                     Asus 6Z     Asus                6Z
#
#       Battery capacity (mAh)  Screen size (inches) Touchscreen  Resolution x  \
# 1358                    2150                  5.00         Yes           480
# 436                     1500                  4.00         Yes           480
# ...

# %%
# we cant find out corr in this laibrary beacuse 2 of them is in string
selected_columns = ['Front camera' , 'Price']
correlation_matrix = upd_df[selected_columns].corr()
print(correlation_matrix)
# Out:
#               Front camera     Price
# Front camera      1.000000  0.134245
# Price             0.134245  1.000000

# %%
mean_prices = upd_df.groupby('Wi-Fi')['Price'].mean()
print(mean_prices)
# Out:
# Wi-Fi
# No      8749.500000
# Yes    17447.584337
# Name: Price, dtype: float64

# %%
mean_prices = upd_df.groupby('Operating system')['Price'].mean()
print(mean_prices)
# Out:
# Operating system
# Android     16277.211409
# Cyanogen     8299.000000
# Tizen        4459.666667
# Windows     11903.272727
# iOS         45510.470588
# Name: Price, dtype: float64

# %%
mean_prices = upd_df.groupby('Wi-Fi')['Price'].mean()
print(mean_prices)
# Out:
# Wi-Fi
# No      8749.500000
# Yes    17447.584337
# Name: Price, dtype: float64

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt

# Scatter plot of 'Front camera' against 'Price'
plt.scatter(upd_df['Front camera'], upd_df['Price'])
plt.xlabel('Front camera')
plt.ylabel('Price')
plt.title('Scatter plot of Front camera vs Price')
plt.show()

# %%
import matplotlib.pyplot as plt

#scatter plot of 'Operating system' against 'Price'
plt.scatter(df['Operating system'], df['Price'])
plt.xlabel('Operating system')
plt.ylabel('Price')
plt.title('Scatter plot of Operating system vs Price')
plt.show()

# %%
import matplotlib.pyplot as plt

#scatter plot of 'Wi-Fi' against 'Price'
plt.scatter(upd_df['Wi-Fi'], upd_df['Price'])
plt.xlabel('Wi-Fi')
plt.ylabel('Price')
plt.grid()
plt.title('Scatter plot of Wi-Fi vs Price')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.bar(upd_df['Operating system'], upd_df['Price'])
plt.xlabel('Operating system')
plt.ylabel('Price')
plt.title('Price by Operating system')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.bar(upd_df['Wi-Fi'], upd_df['Price'])
plt.xlabel('Wi-Fi')
plt.ylabel('Price')
plt.title('Price by Wi-Fi')
plt.show()

# %%
# Plot 'Price' against 'Front camera'
plt.bar(upd_df['Front camera'], upd_df['Price'])
plt.xlabel('Front camera')
plt.ylabel('Price')
plt.title('Price by Front camera')
plt.show()

# %%
plt.plot(upd_df['Operating system'], upd_df['Price'], marker='o', linestyle='-')
plt.xlabel('Operating system')
plt.ylabel('Price')
plt.title('Price by Operating system')
plt.show()

# %%
plt.plot(df['Front camera'], df['Price'], marker='o', linestyle='-')
plt.xlabel('Front camera')
plt.ylabel('Price')
plt.title('Price by Front camera')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot(upd_df['Front camera'], upd_df['Price'], color='blue', marker="o", linestyle='-', label='Front camera')
plt.plot(upd_df['Operating system'], upd_df['Price'], color='red', marker="s", linestyle='--', label='Operating system')
plt.plot(upd_df['Wi-Fi'], upd_df['Price'], color='green', marker="^", linestyle=':', label='Wi-Fi')

plt.xlabel('Index')
plt.ylabel('Price')
plt.title('Price by Category')
plt.legend(loc='best', fontsize='large', labelcolor='blue')  
plt.show()

# %%
plt.plot(upd_df['Wi-Fi'], upd_df['Price'], color='green', marker="^", linestyle=':', label='Wi-Fi')
plt.xlabel('Index')
plt.ylabel('Price')
plt.title('Price by Category')
plt.legend(title='Category', loc='best')
plt.grid()
plt.show()

# %%
plt.plot(df['Front camera'], df['Price'], color='blue', marker="o", linestyle='-', label='Front camera')
plt.xlabel('Index')
plt.ylabel('Price')
plt.title('Price by Category')
plt.legend(title='Category', loc='best')
plt.grid()
plt.show()

# %%
plt.plot(upd_df['Operating system'], upd_df['Price'], color='red', marker="s", linestyle='--', label='Operating system')
plt.xlabel('Index')
plt.ylabel('Price')
plt.title('Price by Category')
plt.legend(title='Category', loc='best')
plt.grid()
plt.show()

# %%
upd_df["Price"].plot(kind="bar")
# this will tell us the occurance of dublicated values in the dataset
upd_df["Price"].value_counts()
# Out:
# Price
# 8999     14
# 6999     10
# 7999      9
# 9999      8
# 10990     6
#          ..
# 6899      1
# 17999     1
# 27900     1
# 29950     1
# 15300     1
# Name: count, Length: 217, dtype: int64

# %%
plt.plot(upd_df['Operating system'], upd_df['Price'] , 'r+', label='Price',linestyle='dotted' , alpha=1 )
plt.legend()

# %%
plt.bar(upd_df['Operating system'], upd_df['Price'] , color="lavender")

plt.xlabel('Operating System')
plt.ylabel('Price (in RS)')
plt.xticks(rotation=45)
plt.title('Operating System vs Price Comparison')
plt.show()

# %%
plt.bar(upd_df['Wi-Fi'], upd_df['Price'] , color="sienna")
plt.xlabel('Operating System')
plt.ylabel('Price (in RS)')
plt.title('wifi vs Price Comparison')
plt.show()

# %%
plt.bar(upd_df['Front camera'], upd_df['Price'] , color="slategray")

plt.xlabel('Operating System')
plt.ylabel('Price (in RS)')
plt.xticks(rotation=45)
plt.title('Front camera vs Price Comparison')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

op_system = upd_df['Operating system']
price = upd_df['Price']
front_camera = upd_df['Front camera']
wifi = upd_df['Wi-Fi']
plt.figure(figsize=(10, 6))
plt.bar(op_system, price, color="indianred", label='Operating System')
plt.bar(front_camera, price, color="darkcyan", label='Front Camera')
plt.bar(wifi, price, color="orange", label='Wi-Fi')

plt.xlabel('Operating System / Front Camera / Wi-Fi')
plt.ylabel('Price')
plt.title('Impact of Operating System, Front Camera, and WiFi on Price')
plt.legend()
plt.grid(True)
plt.xticks(rotation=90) 
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

op_system = upd_df['Operating system']
price = upd_df['Price']
front_camera = upd_df['Front camera']
wifi = upd_df['Wi-Fi']
plt.figure(figsize=(10, 6))
plt.scatter(op_system, price, color="indianred", label='Operating System')
plt.scatter(front_camera, price, color="darkcyan", label='Front Camera')
plt.scatter(wifi, price, color="orange", label='Wi-Fi')

plt.xlabel('Operating System / Front Camera / Wi-Fi')
plt.ylabel('Price')
plt.title('Impact of Operating System, Front Camera, and WiFi on Price')
plt.legend()
plt.grid(True)
plt.xticks(rotation=90) 
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the CSV file into a DataFrame
upd_df = pd.read_csv('ndtv_data_final.csv')

# Selecting the desired columns
selected_columns = ['Operating system', 'Price', 'Front camera', 'Wi-Fi']
selected_df = upd_df[selected_columns]

# Encode categorical variables (one-hot encoding)
selected_df_encoded = pd.get_dummies(selected_df)

# Create a heatmap of the correlation matrix with a different color palette
plt.figure(figsize=(10, 8))
sns.heatmap(data=selected_df_encoded.corr(), annot=True, cmap='viridis', fmt=".2f", vmin=-1, vmax=1 ,linewidth=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

numeric_columns = upd_df.select_dtypes(include=['int', 'float']).columns
selected_df = upd_df[numeric_columns]

plt.figure(figsize=(10, 6))
sns.heatmap(data=selected_df.corr(), annot=True, fmt=".2f", vmin=-1, vmax=1 ,linewidth=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
import seaborn as sns
sns.scatterplot(data=upd_df, x='Operating system', y='Price', hue='Front camera', style='Wi-Fi', size='Front camera')
# Out:
# <Axes: xlabel='Operating system', ylabel='Price'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

selected_columns = ['Operating system', 'Price', 'Front camera', 'Wi-Fi']
selected_df = upd_df[selected_columns]
sns.violinplot(data=selected_df, x='Operating system', y='Price')
plt.title('Violin Plot of Operating System vs. Price')
plt.xlabel('Operating System')
plt.ylabel('Price')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
selected_columns = ['Operating system', 'Price', 'Front camera', 'Wi-Fi']
selected_df = upd_df[selected_columns]
sns.boxplot(data=selected_df, x='Operating system', y='Price')
plt.title('Box Plot of Operating System vs. Price')
plt.xlabel('Operating System')
plt.ylabel('Price')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
selected_columns = ['Operating system', 'Price', 'Front camera', 'Wi-Fi']
selected_df = upd_df[selected_columns]
sns.barplot(data=selected_df, x='Operating system', y='Price')
plt.title('Bar Plot of Operating System vs. Price')
plt.xlabel('Operating System')
plt.ylabel('Price')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
front_camera_bins = pd.cut(upd_df['Front camera'], bins=5) 
sns.histplot(data=upd_df, x='Price', hue=front_camera_bins, multiple='stack', bins=20, kde=True)
plt.title('Price Distribution by Front Camera')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.legend(title='Front Camera')
plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(data=upd_df, x='Wi-Fi', y='Price', hue='Wi-Fi', palette='Set1', alpha=0.7)
plt.title('Scatter Plot of Wi-Fi Availability vs. Price')
plt.xlabel('Wi-Fi Availability')
plt.ylabel('Price')
plt.tight_layout()
plt.show()
